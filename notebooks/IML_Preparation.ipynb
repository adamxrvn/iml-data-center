# %%
# !git clone https://github.com/adamxrvn/iml-data-center.git
# Out:
# fatal: destination path 'iml-data-center' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
base_path = 'iml-data-center/data/controlled_tests/'

data_files = [
'AirFlow_Control.csv', 'Chemical.csv', 'DP_Rack_1.csv', 'DP_Rack_2.csv',
'DP_Room.csv', 'Energy_AirCon.csv', 'Energy_Fan.csv', 'Energy_Heater.csv',
'Energy_PUE.csv', 'Energy_Rack.csv', 'Outside_Temp_RH.csv', 'RH_Cold_Rack_1.csv',
'RH_Cold_Rack_2.csv', 'RH_Hot_Rack_1.csv', 'RH_Hot_Rack_2.csv', 'RH_Room.csv',
'Temp_Cold_Rack_1.csv', 'Temp_Cold_Rack_2.csv', 'Temp_Control.csv',
'Temp_Hot_Rack_1.csv', 'Temp_Hot_Rack_2.csv', 'Temp_Room.csv'
]

experiment_number = 25


df1 = pd.read_csv(f'{base_path}{experiment_number}/{data_files[0]}')

# %%
df1
# Out:
#                  Timestamp  AirFlow-Total  AirFlow-SP
# 0      2018-11-02 13:00:04        4710.44        2500
# 1      2018-11-02 13:00:09        3423.41        2500
# 2      2018-11-02 13:00:14        1703.20        2500
# 3      2018-11-02 13:00:19        1152.19        2500
# 4      2018-11-02 13:00:24        2775.18        2500
# ...                    ...            ...         ...
# 21595  2018-11-03 18:59:39       11739.00       12500
# 21596  2018-11-03 18:59:44       10011.90       12500
# 21597  2018-11-03 18:59:49       11981.90       12500
# 21598  2018-11-03 18:59:54       14271.80       12500
# 21599  2018-11-03 18:59:59       11614.60       12500
#
# [21600 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21600 entries, 0 to 21599
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Timestamp      21600 non-null  object
#  1   AirFlow-Total  21600 non-null  float64
#  2   AirFlow-SP     21600 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 506.4+ KB

# %%
df1.describe()
# Out:
#        AirFlow-Total   AirFlow-SP
# count   21600.000000  21600.00000
# mean     7504.084413   7500.00000
# std      3728.448897   3535.61575
# min       547.514000   2500.00000
# 25%      4732.107500   5000.00000
# 50%      7407.040000   7500.00000
# 75%     10450.000000  10000.00000
# max     17045.500000  12500.00000

# %%
def transform_dataset(df1):
  df1['Timestamp'] = pd.to_datetime(df1['Timestamp'])
  df1.sort_values(['Timestamp'], ascending=True, inplace=True)
  df1.set_index('Timestamp', inplace=True)
  return df1

# %%
transform_dataset(df1)
# Out:
#                      AirFlow-Total  AirFlow-SP
# Timestamp
# 2018-11-02 13:00:04        4710.44        2500
# 2018-11-02 13:00:09        3423.41        2500
# 2018-11-02 13:00:14        1703.20        2500
# 2018-11-02 13:00:19        1152.19        2500
# 2018-11-02 13:00:24        2775.18        2500
# ...                            ...         ...
# 2018-11-03 18:59:39       11739.00       12500
# 2018-11-03 18:59:44       10011.90       12500
# 2018-11-03 18:59:49       11981.90       12500
# 2018-11-03 18:59:54       14271.80       12500
# 2018-11-03 18:59:59       11614.60       12500
#
# [21600 rows x 2 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21600 entries, 2018-11-02 13:00:04 to 2018-11-03 18:59:59
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AirFlow-Total  21600 non-null  float64
#  1   AirFlow-SP     21600 non-null  int64
# dtypes: float64(1), int64(1)
# memory usage: 506.2 KB

# %%
fig = px.line(df1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
experiment_number = 26
df2 = pd.read_csv(f'{base_path}{experiment_number}/{data_files[0]}')
transform_dataset(df2)
# Out:
#                      AirFlow-Total  AirFlow-SP
# Timestamp
# 2018-11-05 11:00:04        4467.80        2500
# 2018-11-05 11:00:09        2842.05        2500
# 2018-11-05 11:00:14        1433.62        2500
# 2018-11-05 11:00:19        1400.51        2500
# 2018-11-05 11:00:24        3499.69        2500
# ...                            ...         ...
# 2018-11-06 16:59:39       10165.60       12500
# 2018-11-06 16:59:44       12725.70       12500
# 2018-11-06 16:59:49       16474.40       12500
# 2018-11-06 16:59:54       13396.00       12500
# 2018-11-06 16:59:59        9844.77       12500
#
# [21600 rows x 2 columns]

# %%
fig = px.line(df2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# we can merge by dates and experiments

# %%
experiment_number = 26
df3 = pd.read_csv(f'{base_path}{experiment_number}/{data_files[1]}')
transform_dataset(df3)
# Out:
#                        NO2   H2S    SO2
# Timestamp
# 2018-11-05 11:00:06  0.090  0.00 -0.044
# 2018-11-05 11:01:06  0.090  0.00 -0.044
# 2018-11-05 11:02:06  0.090  0.00 -0.044
# 2018-11-05 11:03:06  0.090  0.00 -0.044
# 2018-11-05 11:04:06  0.090  0.00 -0.044
# ...                    ...   ...    ...
# 2018-11-06 16:55:06  0.182  0.00 -0.043
# 2018-11-06 16:56:06  0.188  0.00 -0.043
# 2018-11-06 16:57:06  0.182  0.00 -0.044
# 2018-11-06 16:58:06  0.182  0.00 -0.043
# 2018-11-06 16:59:06  0.182  0.08 -0.043
#
# [1800 rows x 3 columns]

# %%
fig = px.line(df3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def merge_datasets():
  base_path = 'iml-data-center/data/controlled_tests/'

  data_files = [
  'AirFlow_Control.csv', 'Chemical.csv', 'DP_Rack_1.csv', 'DP_Rack_2.csv',
  'DP_Room.csv', 'Energy_AirCon.csv', 'Energy_Fan.csv', 'Energy_Heater.csv',
  'Energy_PUE.csv', 'Energy_Rack.csv', 'Outside_Temp_RH.csv', 'RH_Cold_Rack_1.csv',
  'RH_Cold_Rack_2.csv', 'RH_Hot_Rack_1.csv', 'RH_Hot_Rack_2.csv', 'RH_Room.csv',
  'Temp_Cold_Rack_1.csv', 'Temp_Cold_Rack_2.csv', 'Temp_Control.csv',
  'Temp_Hot_Rack_1.csv', 'Temp_Hot_Rack_2.csv', 'Temp_Room.csv'
  ]

  experiment_range = range(25,37)


  for i in experiment_range:
    merged_df = pd.merge(pd.read_csv(f'{base_path}{i}/{data_files[0]}'), pd.read_csv(f'{base_path}{i}/{data_files[1]}'), on='Timestamp', how='outer')

    for f in data_files[2:]:
      next_df = pd.read_csv(f'{base_path}{i}/{f}')
      merged_df = pd.merge(merged_df, next_df, on='Timestamp', how='outer')
      print(len(next_df))

# %%
experiment_range = range(25,37)

all_df = pd.DataFrame()
for i in experiment_range:
  merged_df = pd.merge(pd.read_csv(f'{base_path}{i}/{data_files[0]}'), pd.read_csv(f'{base_path}{i}/{data_files[1]}'), on='Timestamp', how='outer')

  for f in data_files[2:]:
    next_df = pd.read_csv(f'{base_path}{i}/{f}')
    merged_df = pd.merge(merged_df, next_df, on='Timestamp', how='outer')
    # print(len(next_df))
  all_df = pd.concat([all_df, merged_df])

# %%
all_df

# %%
# Disadvantage of this dataset is that it has gaps. Also, different metrics are not synced.
# for example in the experiment 25, almost every file with metrics has 21.6k rows but their timestamps are different in second.
# for example, they have air temperature at time 13:00:01, NO2 level at time 13:00:02, energy consumption at 13:00:03.
# So, we need to sync them. Though, some metrics have twice less rows.

# %%
all_df
# Out:
#                   Timestamp  AirFlow-Total  AirFlow-SP  NO2  H2S  SO2  \
# 0       2018-11-02 13:00:04        4710.44      2500.0  NaN  NaN  NaN
# 1       2018-11-02 13:00:09        3423.41      2500.0  NaN  NaN  NaN
# 2       2018-11-02 13:00:14        1703.20      2500.0  NaN  NaN  NaN
# 3       2018-11-02 13:00:19        1152.19      2500.0  NaN  NaN  NaN
# 4       2018-11-02 13:00:24        2775.18      2500.0  NaN  NaN  NaN
# ...                     ...            ...         ...  ...  ...  ...
# 107995  2018-12-11 16:59:37            NaN         NaN  NaN  NaN  NaN
# 107996  2018-12-11 16:59:42            NaN         NaN  NaN  NaN  NaN
# 107997  2018-12-11 16:59:47            NaN         NaN  NaN  NaN  NaN
# 107998  2018-12-11 16:59:52            NaN         NaN  NaN  NaN  NaN
# 107999  2018-12-11 16:59:57            NaN         NaN  NaN  NaN  NaN
#
#         R1-High-DP  R1-Mild-DP  R1-Low-DP  R2-High-DP  R2-Mild-DP  R2-Low-DP  \
# ...

# %%
transform_dataset(all_df)
# Out:
#                      AirFlow-Total  AirFlow-SP  NO2  H2S  SO2  R1-High-DP  \
# Timestamp
# 2018-11-02 13:00:00            NaN         NaN  NaN  NaN  NaN         NaN
# 2018-11-02 13:00:01            NaN         NaN  NaN  NaN  NaN         NaN
# 2018-11-02 13:00:02            NaN         NaN  NaN  NaN  NaN         NaN
# 2018-11-02 13:00:03            NaN         NaN  NaN  NaN  NaN         NaN
# 2018-11-02 13:00:04        4710.44      2500.0  NaN  NaN  NaN      10.567
# ...                            ...         ...  ...  ...  ...         ...
# 2018-12-15 16:59:55            NaN         NaN  NaN  NaN  NaN         NaN
# 2018-12-15 16:59:56            NaN         NaN  NaN  NaN  NaN         NaN
# 2018-12-15 16:59:57            NaN         NaN  NaN  NaN  NaN         NaN
# 2018-12-15 16:59:58            NaN         NaN  NaN  NaN  NaN         NaN
# 2018-12-15 16:59:59       11891.20     12500.0  NaN  NaN  NaN      35.597
#
# ...

# %%
# fig = px.line(merged_df)
# fig.show()

# %%
all_df.head(10)
# Out:
#                      AirFlow-Total  AirFlow-SP    NO2  H2S    SO2  R1-High-DP  \
# Timestamp
# 2018-11-02 13:00:00            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:01            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:02            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:03            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:04        4710.44      2500.0    NaN  NaN    NaN      10.567
# 2018-11-02 13:00:05            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:06            NaN         NaN  0.188  0.0 -0.043         NaN
# 2018-11-02 13:00:07            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:08            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:09        3423.41      2500.0    NaN  NaN    NaN       5.683
#
#                      R1-Mild-DP  R1-Low-DP  R2-High-DP  R2-Mild-DP  R2-Low-DP  \
# Timestamp
# ...

# %%
pd.options.display.max_columns = 500

# %%
all_df.head(50)
# Out:
#                      AirFlow-Total  AirFlow-SP    NO2  H2S    SO2  R1-High-DP  \
# Timestamp
# 2018-11-02 13:00:00            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:01            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:02            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:03            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:04        4710.44      2500.0    NaN  NaN    NaN      10.567
# 2018-11-02 13:00:05            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:06            NaN         NaN  0.188  0.0 -0.043         NaN
# 2018-11-02 13:00:07            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:08            NaN         NaN    NaN  NaN    NaN         NaN
# 2018-11-02 13:00:09        3423.41      2500.0    NaN  NaN    NaN       5.683
# 2018-11-02 13:00:10            NaN         NaN    NaN  NaN    NaN         NaN
# ...

# %%
all_df = all_df.fillna(-99909)

# %%
all_df = all_df.resample('5S').max()

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 745920 entries, 2018-11-02 13:00:00 to 2018-12-15 16:59:55
# Freq: 5S
# Columns: 125 entries, AirFlow-Total to Hot-R4-Low-TEMP_y
# dtypes: float64(125)
# memory usage: 717.1 MB

# %%
all_df
# Out:
#                      AirFlow-Total  AirFlow-SP        NO2      H2S        SO2  \
# Timestamp
# 2018-11-02 13:00:00        4710.44      2500.0 -99909.000 -99909.0 -99909.000
# 2018-11-02 13:00:05        3423.41      2500.0      0.188      0.0     -0.043
# 2018-11-02 13:00:10        1703.20      2500.0 -99909.000 -99909.0 -99909.000
# 2018-11-02 13:00:15        1152.19      2500.0 -99909.000 -99909.0 -99909.000
# 2018-11-02 13:00:20        2775.18      2500.0 -99909.000 -99909.0 -99909.000
# ...                            ...         ...        ...      ...        ...
# 2018-12-15 16:59:35       11342.00     12500.0 -99909.000 -99909.0 -99909.000
# 2018-12-15 16:59:40       11625.40     12500.0 -99909.000 -99909.0 -99909.000
# 2018-12-15 16:59:45       13292.70     12500.0 -99909.000 -99909.0 -99909.000
# 2018-12-15 16:59:50       13416.60     12500.0 -99909.000 -99909.0 -99909.000
# 2018-12-15 16:59:55       11891.20     12500.0 -99909.000 -99909.0 -99909.000
#
# ...

# %%
all_df.replace(-99909, np.nan, inplace=True)

# %%
all_df
# Out:
#                      AirFlow-Total  AirFlow-SP    NO2  H2S    SO2  R1-High-DP  \
# Timestamp
# 2018-11-02 13:00:00        4710.44      2500.0    NaN  NaN    NaN      10.567
# 2018-11-02 13:00:05        3423.41      2500.0  0.188  0.0 -0.043       5.683
# 2018-11-02 13:00:10        1703.20      2500.0    NaN  NaN    NaN       3.241
# 2018-11-02 13:00:15        1152.19      2500.0    NaN  NaN    NaN       3.851
# 2018-11-02 13:00:20        2775.18      2500.0    NaN  NaN    NaN       6.904
# ...                            ...         ...    ...  ...    ...         ...
# 2018-12-15 16:59:35       11342.00     12500.0    NaN  NaN    NaN      31.324
# 2018-12-15 16:59:40       11625.40     12500.0    NaN  NaN    NaN      41.703
# 2018-12-15 16:59:45       13292.70     12500.0    NaN  NaN    NaN      49.639
# 2018-12-15 16:59:50       13416.60     12500.0    NaN  NaN    NaN      40.481
# 2018-12-15 16:59:55       11891.20     12500.0    NaN  NaN    NaN      35.597
#
# ...

# %%
df = all_df
df_stat = pd.concat(
    {
        "# of NaN's": df.isna().sum(),
        "% of NaN's": round(df.isna().sum() / df.shape[0] * 100, 2),
        "# of zeros": df.isin([0]).sum(),
        "% of zeros": round(df.isin([0]).sum() / df.shape[0] * 100, 2),
        "# of Unique Values": df.nunique(),
        "Data Type": df.dtypes

    }, axis=1)

# %%
df_stat
# Out:
#                     # of NaN's  % of NaN's  # of zeros  % of zeros  \
# AirFlow-Total           486720       65.25           0        0.00
# AirFlow-SP              486720       65.25           0        0.00
# NO2                     724320       97.10           0        0.00
# H2S                     724320       97.10       16238        2.18
# SO2                     724320       97.10        8357        1.12
# ...                        ...         ...         ...         ...
# Hot-R3-Mild-TEMP_y      702720       94.21           0        0.00
# Hot-R3-Low-TEMP_y       702720       94.21           0        0.00
# Hot-R4-High-TEMP_y      702720       94.21           0        0.00
# Hot-R4-Mild-TEMP_y      702720       94.21           0        0.00
# Hot-R4-Low-TEMP_y       702720       94.21           0        0.00
#
#                     # of Unique Values Data Type
# AirFlow-Total                    75636   float64
# AirFlow-SP                           6   float64
# ...

# %%
df.drop(['Heater-P3','AC-Total','AC-P1','AC-P2','AC-P3','Damper'],inplace=True, axis=1)
# Out:
# <ipython-input-89-4b28dfb013eb>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
inx = df.index

# %%
for i in range(0, len(inx) - 1):
    time_difference = inx[i + 1] - inx[i]
    if time_difference.seconds != 5:
      print(time_difference, inx[i])
# Out:
# 1 days 16:00:05 2018-11-03 18:59:55
# 5 days 18:00:05 2018-11-06 16:59:55
# 2 days 18:00:05 2018-11-13 16:59:55
# 1 days 18:00:05 2018-11-17 16:59:55
# 5 days 18:00:05 2018-11-20 16:59:55
# 0 days 18:00:05 2018-11-27 16:59:55
# 0 days 18:00:05 2018-11-29 16:59:55
# 3 days 18:00:05 2018-12-01 16:59:55
# 0 days 18:00:05 2018-12-06 16:59:55
# 1 days 18:00:05 2018-12-08 16:59:55
# 2 days 18:00:05 2018-12-11 16:59:55

# %%
df
# Out:
#                      AirFlow-Total  AirFlow-SP        NO2      H2S        SO2  \
# Timestamp
# 2018-11-02 13:00:00        4710.44      2500.0 -99909.000 -99909.0 -99909.000
# 2018-11-02 13:00:05        3423.41      2500.0      0.188      0.0     -0.043
# 2018-11-02 13:00:10        1703.20      2500.0 -99909.000 -99909.0 -99909.000
# 2018-11-02 13:00:15        1152.19      2500.0 -99909.000 -99909.0 -99909.000
# 2018-11-02 13:00:20        2775.18      2500.0 -99909.000 -99909.0 -99909.000
# ...                            ...         ...        ...      ...        ...
# 2018-12-15 16:59:35       11342.00     12500.0 -99909.000 -99909.0 -99909.000
# 2018-12-15 16:59:40       11625.40     12500.0 -99909.000 -99909.0 -99909.000
# 2018-12-15 16:59:45       13292.70     12500.0 -99909.000 -99909.0 -99909.000
# 2018-12-15 16:59:50       13416.60     12500.0 -99909.000 -99909.0 -99909.000
# 2018-12-15 16:59:55       11891.20     12500.0 -99909.000 -99909.0 -99909.000
#
# ...

# %%
df = result_df
df_stat = pd.concat(
    {
        "# of NaN's": df.isna().sum(),
        "% of NaN's": round(df.isna().sum() / df.shape[0] * 100, 2),
        "# of zeros": df.isin([0]).sum(),
        "% of zeros": round(df.isin([0]).sum() / df.shape[0] * 100, 2),
        "# of Unique Values": df.nunique(),
        "Data Type": df.dtypes

    }, axis=1)

# %%
df_stat
# Out:
#                  # of NaN's  % of NaN's  # of zeros  % of zeros  \
# AirFlow-Total             0        0.00           0        0.00
# AirFlow-SP                0        0.00           0        0.00
# NO2                   19800       91.67           0        0.00
# H2S                   19800       91.67        1194        5.53
# SO2                   19800       91.67        1157        5.36
# ...                     ...         ...         ...         ...
# Hot-R4-Low-TEMP           0        0.00           0        0.00
# RA-Mixing-TEMP        14400       66.67           0        0.00
# RA-Cold-TEMP          14400       66.67           0        0.00
# RA-Hot-TEMP           14400       66.67           0        0.00
# RA-Exhaust-TEMP       14400       66.67           0        0.00
#
#                  # of Unique Values Data Type
# AirFlow-Total                 18148   float64
# AirFlow-SP                        5   float64
# NO2                               9   float64
# ...

# %%
# We will switch to another dataset since this is one is too leaky
